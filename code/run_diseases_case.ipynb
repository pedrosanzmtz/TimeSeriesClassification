# %%
from __future__ import print_function
from __future__ import absolute_import
from sklearn import preprocessing
import pandas as pd
import numpy as np
from pipeline_gridsearch import *

# %%
def get_data():
    df = pd.read_csv("../data/diseases.csv")
    X = df.iloc[:, :-1]
    X_true = X.sum(axis=1) > 0
    X = X[X_true]
    le = preprocessing.LabelEncoder()
    y = pd.Series(le.fit(df['class']).transform(df['class']))
    y = y[X_true]
    return X, y

# %%
def main():
    X, y = get_data()
    out = open('../results/performances/diseases_performance.csv', 'w')
    out.write('model,slice,acc,mse,time\n')
    n_weeks = 6
    name = 'diseases'
    na_values = np.nan
    for i in range(1, n_weeks + 1):
        sub = str(i) + 'W'
        sub_X = X.iloc[:, :-i]
        sub_X = sub_X.dropna(how='all', axis=0)
        indx = sub_X.index
        sub_y = y[indx]
        print("subX shape:", sub_X.shape)
        print("suby shape:", y.shape)
        sub_X = preprocess(sub_X, na_values)
        run_pipeline(sub_X, sub_y, 10, out, sub, name)

# %%
main()
# Out:
# subX shape: (3230, 12)
# suby shape: (3230,)
# Performing model optimizations...
#
# Estimator: LR
# Params Test:
# 0.923 (+/-0.011) for {'clf__C': 0.3, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.923 (+/-0.011) for {'clf__C': 0.3, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# 0.928 (+/-0.012) for {'clf__C': 0.5, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.928 (+/-0.012) for {'clf__C': 0.5, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# 0.935 (+/-0.010) for {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.935 (+/-0.010) for {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# Best params: {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# Best training accuracy: 0.935
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.062
# Total time: 0.79
#
# Estimator: RF
# Params Test:
# 0.963 (+/-0.017) for {'clf__criterion': 'gini', 'clf__n_estimators': 10}
# 0.963 (+/-0.019) for {'clf__criterion': 'gini', 'clf__n_estimators': 20}
# 0.964 (+/-0.018) for {'clf__criterion': 'gini', 'clf__n_estimators': 30}
# 0.964 (+/-0.014) for {'clf__criterion': 'entropy', 'clf__n_estimators': 10}
# 0.963 (+/-0.018) for {'clf__criterion': 'entropy', 'clf__n_estimators': 20}
# 0.964 (+/-0.019) for {'clf__criterion': 'entropy', 'clf__n_estimators': 30}
# Best params: {'clf__criterion': 'gini', 'clf__n_estimators': 30}
# Best training accuracy: 0.964
# Test set accuracy score for best params: 0.98
# Test set mse score for best params: 0.023
# Total time: 4.06
#
# Estimator: SVM
# Params Test:
# 0.898 (+/-0.025) for {'clf__C': 0.3, 'clf__kernel': 'sigmoid'}
# 0.924 (+/-0.014) for {'clf__C': 0.3, 'clf__kernel': 'rbf'}
# 0.898 (+/-0.026) for {'clf__C': 0.5, 'clf__kernel': 'sigmoid'}
# 0.930 (+/-0.012) for {'clf__C': 0.5, 'clf__kernel': 'rbf'}
# 0.899 (+/-0.025) for {'clf__C': 1, 'clf__kernel': 'sigmoid'}
# 0.938 (+/-0.014) for {'clf__C': 1, 'clf__kernel': 'rbf'}
# Best params: {'clf__C': 1, 'clf__kernel': 'rbf'}
# Best training accuracy: 0.938
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.062
# Total time: 1.65
#
# Estimator: MLP
# Params Test:
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'sgd'}
# 0.915 (+/-0.012) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'adam'}
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'sgd'}
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# 0.915 (+/-0.012) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'sgd'}
# 0.932 (+/-0.009) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'adam'}
# 0.915 (+/-0.012) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'sgd'}
# 0.939 (+/-0.013) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# Best params: {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# Best training accuracy: 0.939
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.059
# Total time: 40.15
# subX shape: (3230, 11)
# suby shape: (3230,)
# Performing model optimizations...
#
# Estimator: LR
# Params Test:
# 0.923 (+/-0.011) for {'clf__C': 0.3, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.923 (+/-0.011) for {'clf__C': 0.3, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# 0.928 (+/-0.013) for {'clf__C': 0.5, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.928 (+/-0.013) for {'clf__C': 0.5, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# 0.935 (+/-0.011) for {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.935 (+/-0.011) for {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# Best params: {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# Best training accuracy: 0.935
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.062
# Total time: 0.79
#
# Estimator: RF
# Params Test:
# 0.959 (+/-0.024) for {'clf__criterion': 'gini', 'clf__n_estimators': 10}
# 0.960 (+/-0.020) for {'clf__criterion': 'gini', 'clf__n_estimators': 20}
# 0.960 (+/-0.020) for {'clf__criterion': 'gini', 'clf__n_estimators': 30}
# 0.956 (+/-0.025) for {'clf__criterion': 'entropy', 'clf__n_estimators': 10}
# 0.958 (+/-0.021) for {'clf__criterion': 'entropy', 'clf__n_estimators': 20}
# 0.959 (+/-0.020) for {'clf__criterion': 'entropy', 'clf__n_estimators': 30}
# Best params: {'clf__criterion': 'gini', 'clf__n_estimators': 30}
# Best training accuracy: 0.960
# Test set accuracy score for best params: 0.97
# Test set mse score for best params: 0.025
# Total time: 2.48
#
# Estimator: SVM
# Params Test:
# 0.890 (+/-0.027) for {'clf__C': 0.3, 'clf__kernel': 'sigmoid'}
# 0.923 (+/-0.015) for {'clf__C': 0.3, 'clf__kernel': 'rbf'}
# 0.887 (+/-0.037) for {'clf__C': 0.5, 'clf__kernel': 'sigmoid'}
# 0.931 (+/-0.012) for {'clf__C': 0.5, 'clf__kernel': 'rbf'}
# 0.890 (+/-0.033) for {'clf__C': 1, 'clf__kernel': 'sigmoid'}
# 0.936 (+/-0.014) for {'clf__C': 1, 'clf__kernel': 'rbf'}
# Best params: {'clf__C': 1, 'clf__kernel': 'rbf'}
# Best training accuracy: 0.936
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.061
# Total time: 1.54
#
# Estimator: MLP
# Params Test:
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'sgd'}
# 0.915 (+/-0.012) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'adam'}
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'sgd'}
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# 0.915 (+/-0.012) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'sgd'}
# 0.932 (+/-0.008) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'adam'}
# 0.915 (+/-0.012) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'sgd'}
# 0.939 (+/-0.013) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# Best params: {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# Best training accuracy: 0.939
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.059
# Total time: 40.66
# subX shape: (3230, 10)
# suby shape: (3230,)
# Performing model optimizations...
#
# Estimator: LR
# Params Test:
# 0.923 (+/-0.012) for {'clf__C': 0.3, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.923 (+/-0.012) for {'clf__C': 0.3, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# 0.928 (+/-0.013) for {'clf__C': 0.5, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.928 (+/-0.013) for {'clf__C': 0.5, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# 0.935 (+/-0.011) for {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.935 (+/-0.011) for {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# Best params: {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# Best training accuracy: 0.935
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.062
# Total time: 0.77
#
# Estimator: RF
# Params Test:
# 0.957 (+/-0.017) for {'clf__criterion': 'gini', 'clf__n_estimators': 10}
# 0.957 (+/-0.023) for {'clf__criterion': 'gini', 'clf__n_estimators': 20}
# 0.957 (+/-0.020) for {'clf__criterion': 'gini', 'clf__n_estimators': 30}
# 0.955 (+/-0.019) for {'clf__criterion': 'entropy', 'clf__n_estimators': 10}
# 0.955 (+/-0.017) for {'clf__criterion': 'entropy', 'clf__n_estimators': 20}
# 0.957 (+/-0.018) for {'clf__criterion': 'entropy', 'clf__n_estimators': 30}
# Best params: {'clf__criterion': 'entropy', 'clf__n_estimators': 30}
# Best training accuracy: 0.957
# Test set accuracy score for best params: 0.97
# Test set mse score for best params: 0.035
# Total time: 2.54
#
# Estimator: SVM
# Params Test:
# 0.905 (+/-0.013) for {'clf__C': 0.3, 'clf__kernel': 'sigmoid'}
# 0.925 (+/-0.016) for {'clf__C': 0.3, 'clf__kernel': 'rbf'}
# 0.902 (+/-0.019) for {'clf__C': 0.5, 'clf__kernel': 'sigmoid'}
# 0.930 (+/-0.015) for {'clf__C': 0.5, 'clf__kernel': 'rbf'}
# 0.903 (+/-0.020) for {'clf__C': 1, 'clf__kernel': 'sigmoid'}
# 0.937 (+/-0.012) for {'clf__C': 1, 'clf__kernel': 'rbf'}
# Best params: {'clf__C': 1, 'clf__kernel': 'rbf'}
# Best training accuracy: 0.937
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.061
# Total time: 1.43
#
# Estimator: MLP
# Params Test:
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'sgd'}
# 0.915 (+/-0.012) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'adam'}
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'sgd'}
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# 0.915 (+/-0.012) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'sgd'}
# 0.933 (+/-0.011) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'adam'}
# 0.915 (+/-0.012) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'sgd'}
# 0.939 (+/-0.013) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# Best params: {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# Best training accuracy: 0.939
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.059
# Total time: 42.32
# subX shape: (3230, 9)
# suby shape: (3230,)
# Performing model optimizations...
#
# Estimator: LR
# Params Test:
# 0.923 (+/-0.012) for {'clf__C': 0.3, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.923 (+/-0.012) for {'clf__C': 0.3, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# 0.927 (+/-0.013) for {'clf__C': 0.5, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.927 (+/-0.013) for {'clf__C': 0.5, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# 0.935 (+/-0.011) for {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.935 (+/-0.011) for {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# Best params: {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# Best training accuracy: 0.935
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.062
# Total time: 0.77
#
# Estimator: RF
# Params Test:
# 0.957 (+/-0.026) for {'clf__criterion': 'gini', 'clf__n_estimators': 10}
# 0.957 (+/-0.025) for {'clf__criterion': 'gini', 'clf__n_estimators': 20}
# 0.957 (+/-0.023) for {'clf__criterion': 'gini', 'clf__n_estimators': 30}
# 0.955 (+/-0.023) for {'clf__criterion': 'entropy', 'clf__n_estimators': 10}
# 0.957 (+/-0.028) for {'clf__criterion': 'entropy', 'clf__n_estimators': 20}
# 0.957 (+/-0.029) for {'clf__criterion': 'entropy', 'clf__n_estimators': 30}
# Best params: {'clf__criterion': 'gini', 'clf__n_estimators': 30}
# Best training accuracy: 0.957
# Test set accuracy score for best params: 0.97
# Test set mse score for best params: 0.029
# Total time: 2.45
#
# Estimator: SVM
# Params Test:
# 0.909 (+/-0.016) for {'clf__C': 0.3, 'clf__kernel': 'sigmoid'}
# 0.925 (+/-0.014) for {'clf__C': 0.3, 'clf__kernel': 'rbf'}
# 0.907 (+/-0.017) for {'clf__C': 0.5, 'clf__kernel': 'sigmoid'}
# 0.931 (+/-0.014) for {'clf__C': 0.5, 'clf__kernel': 'rbf'}
# 0.909 (+/-0.015) for {'clf__C': 1, 'clf__kernel': 'sigmoid'}
# 0.936 (+/-0.011) for {'clf__C': 1, 'clf__kernel': 'rbf'}
# Best params: {'clf__C': 1, 'clf__kernel': 'rbf'}
# Best training accuracy: 0.936
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.063
# Total time: 1.42
#
# Estimator: MLP
# Params Test:
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'sgd'}
# 0.915 (+/-0.012) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'adam'}
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'sgd'}
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# 0.915 (+/-0.012) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'sgd'}
# 0.931 (+/-0.010) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'adam'}
# 0.915 (+/-0.012) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'sgd'}
# 0.939 (+/-0.014) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# Best params: {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# Best training accuracy: 0.939
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.059
# Total time: 42.00
# subX shape: (3212, 8)
# suby shape: (3230,)
# Performing model optimizations...
#
# Estimator: LR
# Params Test:
# 0.928 (+/-0.017) for {'clf__C': 0.3, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.928 (+/-0.017) for {'clf__C': 0.3, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# 0.934 (+/-0.018) for {'clf__C': 0.5, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.934 (+/-0.018) for {'clf__C': 0.5, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# 0.938 (+/-0.021) for {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.938 (+/-0.021) for {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# Best params: {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# Best training accuracy: 0.938
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.063
# Total time: 0.88
#
# Estimator: RF
# Params Test:
# 0.961 (+/-0.027) for {'clf__criterion': 'gini', 'clf__n_estimators': 10}
# 0.961 (+/-0.025) for {'clf__criterion': 'gini', 'clf__n_estimators': 20}
# 0.962 (+/-0.024) for {'clf__criterion': 'gini', 'clf__n_estimators': 30}
# 0.959 (+/-0.030) for {'clf__criterion': 'entropy', 'clf__n_estimators': 10}
# 0.961 (+/-0.029) for {'clf__criterion': 'entropy', 'clf__n_estimators': 20}
# 0.962 (+/-0.026) for {'clf__criterion': 'entropy', 'clf__n_estimators': 30}
# Best params: {'clf__criterion': 'gini', 'clf__n_estimators': 30}
# Best training accuracy: 0.962
# Test set accuracy score for best params: 0.96
# Test set mse score for best params: 0.039
# Total time: 2.57
#
# Estimator: SVM
# Params Test:
# 0.915 (+/-0.010) for {'clf__C': 0.3, 'clf__kernel': 'sigmoid'}
# 0.931 (+/-0.016) for {'clf__C': 0.3, 'clf__kernel': 'rbf'}
# 0.904 (+/-0.017) for {'clf__C': 0.5, 'clf__kernel': 'sigmoid'}
# 0.936 (+/-0.018) for {'clf__C': 0.5, 'clf__kernel': 'rbf'}
# 0.904 (+/-0.019) for {'clf__C': 1, 'clf__kernel': 'sigmoid'}
# 0.939 (+/-0.016) for {'clf__C': 1, 'clf__kernel': 'rbf'}
# Best params: {'clf__C': 1, 'clf__kernel': 'rbf'}
# Best training accuracy: 0.939
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.063
# Total time: 1.39
#
# Estimator: MLP
# Params Test:
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'sgd'}
# 0.913 (+/-0.010) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'adam'}
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'sgd'}
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# 0.913 (+/-0.010) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'sgd'}
# 0.938 (+/-0.020) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'adam'}
# 0.913 (+/-0.010) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'sgd'}
# 0.941 (+/-0.017) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# Best params: {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# Best training accuracy: 0.941
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.063
# Total time: 43.98
# subX shape: (3212, 7)
# suby shape: (3230,)
# Performing model optimizations...
#
# Estimator: LR
# Params Test:
# 0.928 (+/-0.017) for {'clf__C': 0.3, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.928 (+/-0.017) for {'clf__C': 0.3, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# 0.934 (+/-0.018) for {'clf__C': 0.5, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.934 (+/-0.018) for {'clf__C': 0.5, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# 0.938 (+/-0.021) for {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# 0.938 (+/-0.021) for {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg'}
# Best params: {'clf__C': 1, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
# Best training accuracy: 0.938
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.063
# Total time: 0.91
#
# Estimator: RF
# Params Test:
# 0.961 (+/-0.026) for {'clf__criterion': 'gini', 'clf__n_estimators': 10}
# 0.961 (+/-0.025) for {'clf__criterion': 'gini', 'clf__n_estimators': 20}
# 0.961 (+/-0.026) for {'clf__criterion': 'gini', 'clf__n_estimators': 30}
# 0.961 (+/-0.030) for {'clf__criterion': 'entropy', 'clf__n_estimators': 10}
# 0.962 (+/-0.025) for {'clf__criterion': 'entropy', 'clf__n_estimators': 20}
# 0.961 (+/-0.027) for {'clf__criterion': 'entropy', 'clf__n_estimators': 30}
# Best params: {'clf__criterion': 'entropy', 'clf__n_estimators': 20}
# Best training accuracy: 0.962
# Test set accuracy score for best params: 0.96
# Test set mse score for best params: 0.038
# Total time: 2.40
#
# Estimator: SVM
# Params Test:
# 0.915 (+/-0.015) for {'clf__C': 0.3, 'clf__kernel': 'sigmoid'}
# 0.930 (+/-0.019) for {'clf__C': 0.3, 'clf__kernel': 'rbf'}
# 0.909 (+/-0.020) for {'clf__C': 0.5, 'clf__kernel': 'sigmoid'}
# 0.935 (+/-0.019) for {'clf__C': 0.5, 'clf__kernel': 'rbf'}
# 0.908 (+/-0.025) for {'clf__C': 1, 'clf__kernel': 'sigmoid'}
# 0.940 (+/-0.018) for {'clf__C': 1, 'clf__kernel': 'rbf'}
# Best params: {'clf__C': 1, 'clf__kernel': 'rbf'}
# Best training accuracy: 0.940
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.063
# Total time: 1.44
#
# Estimator: MLP
# Params Test:
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'sgd'}
# 0.913 (+/-0.010) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'adam'}
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'sgd'}
# 0.905 (+/-0.004) for {'clf__activation': 'logistic', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# 0.913 (+/-0.010) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'sgd'}
# 0.937 (+/-0.021) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10,), 'clf__solver': 'adam'}
# 0.913 (+/-0.010) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'sgd'}
# 0.941 (+/-0.017) for {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# Best params: {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (10, 5), 'clf__solver': 'adam'}
# Best training accuracy: 0.941
# Test set accuracy score for best params: 0.94
# Test set mse score for best params: 0.063
# Total time: 49.84
